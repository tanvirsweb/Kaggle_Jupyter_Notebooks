# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2

#reading the image as: BGR
image = cv2.imread("/kaggle/input/landscape-pictures/00000002.jpg")
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image2)

# %%
#save the image
cv2.imwrite('testing_save.png',image)
# Out:
# True

# %%
image3 = cv2.imread("/kaggle/working/testing_save.png")
plt.imshow( image4 )
